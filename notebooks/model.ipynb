# %%
import joblib
joblib.dump(model, "../models/antigen_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import joblib
# ----> 2 joblib.dump(model, "../models/antigen_model.pkl")
#
# NameError: name 'model' is not defined
