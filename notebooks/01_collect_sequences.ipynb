# %%
import sys
# !{sys.executable} -m pip install torch transformers pandas scikit-learn umap-learn biopython matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\asmak\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
from Bio import SeqIO

sequences = []
for record in SeqIO.parse("../data/raw/spike_SARS_CoV_2_spike_AND_reviewed_2026_03_27.fasta", "fasta"):
    sequences.append(str(record.seq))

len(sequences)
# Out:
# 97
